# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheshk3010/BASIC-STATS---1-ASSIGNMENT./blob/main/Hypothesis_Testing_assi_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem Statement:
#
# Chi-square test is used to check whether there is a significant
# difference between observed and expected frequencies.

# %%
import numpy as np
from scipy.stats import chi2

# Importing required libraries for calculations

# %%
observed = np.array([50, 30, 20])
expected = np.array([40, 40, 20])

# Observed values are actual data
# Expected values are theoretical values

# %%
chi_square = np.sum((observed - expected)**2 / expected)
chi_square

# Calculating chi-square test statistic
# Out:
# np.float64(5.0)

# %%
df = len(observed) - 1
df

# Degrees of freedom = number of categories - 1
# Out:
# 2

# %%
alpha = 0.05
chi_critical = chi2.ppf(1 - alpha, df)
chi_critical

# Finding critical value using chi-square table
# Out:
# np.float64(5.991464547107979)

# %%
if chi_square > chi_critical:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")

# Comparing test statistic with critical value
# Out:
# Fail to reject the null hypothesis

# %% [markdown]
# Conclusion:
#
# Since the calculated chi-square value is less than the critical value,
# we fail to reject the null hypothesis.
#
# There is no significant difference between the observed and expected frequencies.
