# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheshk3010/BASIC-STATS---1-ASSIGNMENT./blob/main/Hypothesis_testing_assi_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given Data:
#
# Theoretical cost model: W = 1000 + 5X
# Mean units produced per week = 600
# Standard deviation of units = 25
#
# Sample mean weekly cost = 3050
# Sample size = 25
# Significance level (α) = 0.05

# %%
import numpy as np
from scipy import stats

# Importing required libraries

# %% [markdown]
# Hypotheses:
#
# H0: Mean weekly operating cost is equal to the theoretical cost
# H1: Mean weekly operating cost is higher than the theoretical cost

# %%
mu = 1000 + 5 * 600
sigma = 5 * 25

mu, sigma

# Calculating theoretical mean cost and standard deviation
# Out:
# (4000, 125)

# %%
sample_mean = 3050
n = 25

z_value = (sample_mean - mu) / (sigma / np.sqrt(n))
z_value

# Calculating Z test statistic
# Out:
# np.float64(-38.0)

# %%
alpha = 0.05
z_critical = stats.norm.ppf(1 - alpha)

z_critical

# Finding critical value from Z distribution
# Out:
# np.float64(1.6448536269514722)

# %%
if z_value > z_critical:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")

# Comparing test statistic with critical value
# Out:
# Fail to reject the null hypothesis

# %% [markdown]
# Conclusion:
#
# Since the calculated Z value is less than the critical value,
# we fail to reject the null hypothesis.
#
# There is no sufficient evidence to conclude that weekly operating
# costs are higher than the theoretical cost model.
